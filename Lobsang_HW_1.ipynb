# %% [markdown]
# <a href="https://colab.research.google.com/github/loovsang/SQL/blob/main/Lobsang_HW_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #HW #1
# Lobsang Dolma
#
# SQL SELECT, WHERE, DISTICT practice
# 1. Write s select statement to return all columns and rows from the customer table

# %% [markdown]
# ![Screen Shot 2022-08-10 at 9.48.46 PM.png](data:image/png;base64,...)

# %% [markdown]
# 2. Write a query to select first name, last name, and email from customer table.
# ![Screen Shot 2022-08-10 at 9.56.59 PM.png](data:image/png;base64,...)

# %% [markdown]
# 3. Write a query to return all rows and columns from the film table
# ![Screen Shot 2022-08-10 at 10.01.08 PM.png](data:image/png;base64,...)

# %% [markdown]
# 4. write a query to return unique rows from the relase year column in the film table
#
# ![Screen Shot 2022-08-10 at 10.04.25 PM.png](data:image/png;base64,...)

# %% [markdown]
# 5. write a query to return unique rows from the rental rate column in the film table ![Screen Shot 2022-08-10 at 10.06.41 PM.png](data:image/png;base64,...)

# %% [markdown]
# 6. A customer left us some feed back about our store, write a query to find her email address - for Nancy Thomas
# ![Screen Shot 2022-08-10 at 10.09.28 PM.png](data:image/png;base64,...)

# %% [markdown]
# 7. we are trying to find a customer located at certain addres '259 Ipoh Drive' - Can you find her phone number?
# ![Screen Shot 2022-08-10 at 10.13.29 PM.png](data:image/png;base64,...)

# %% [markdown]
# 8. write a query from the customer table, where store id is 1 and address id is greater than 150
# ![Screen Shot 2022-08-10 at 10.30.18 PM.png](data:image/png;base64,...)

# %% [markdown]
# 9. write a query from the payment table where the amount is either 4.99 or 1.99
#
# ![Screen Shot 2022-08-10 at 10.34.53 PM.png](data:image/png;base64,...)

# %% [markdown]
# 10. write a query to return a list of transitions from the payment table where the amount is greater than 5
#
# ![Screen Shot 2022-08-10 at 10.38.13 PM.png](data:image/png;base64,...)
